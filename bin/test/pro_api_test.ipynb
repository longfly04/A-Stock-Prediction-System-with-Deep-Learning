# %%
import tushare as ts
import sys
import pandas as pd
import numpy as np

sys.path.append('C:\\Users\\longf.DESKTOP-7QSFE46\\GitHub\\A-Stock-Prediction-System-with-GAN-and-DRL')

with open('C:\\Users\\longf.DESKTOP-7QSFE46\\GitHub\\A-Stock-Prediction-System-with-GAN-and-DRL\\bin\\base\\token.tkn','r') as token:
    mytoken = token.readline().rstrip('\n')
    print('Your token is ' + mytoken)
    
ts.set_token(mytoken)
data = ts.pro_bar(ts_code='600690.SH', start_date='20190201', end_date='20190301', asset='E', freq='1min', ma=[7, 21])

data
# Out:
# Your token is 52d1d7b3ade4d917050699b12c7f2327fd9c2afa2e21e66f2633a88b
#         ts_code           trade_time   open   high    low  close       vol  \
# 0     600690.SH  2019-02-28 15:00:00  16.48  16.48  16.48  16.48  598800.0
# 1     600690.SH  2019-02-28 14:59:00  16.54  16.54  16.54  16.54       0.0
# 2     600690.SH  2019-02-28 14:58:00  16.54  16.54  16.54  16.54    5700.0
# 3     600690.SH  2019-02-28 14:57:00  16.50  16.54  16.48  16.53  398505.0
# 4     600690.SH  2019-02-28 14:56:00  16.55  16.56  16.50  16.50  777598.0
# 5     600690.SH  2019-02-28 14:55:00  16.53  16.55  16.53  16.54  142018.0
# 6     600690.SH  2019-02-28 14:54:00  16.51  16.55  16.51  16.53  472249.0
# 7     600690.SH  2019-02-28 14:53:00  16.51  16.56  16.51  16.56  803235.0
# 8     600690.SH  2019-02-28 14:52:00  16.55  16.55  16.50  16.51  364165.0
# 9     600690.SH  2019-02-28 14:51:00  16.55  16.55  16.51  16.55  349055.0
# 10    600690.SH  2019-02-28 14:50:00  16.56  16.57  16.52  16.56  179840.0
# ...

# %%
from matplotlib import pyplot as plt


plt.figure()
time = pd.to_datetime(data['trade_time'], format='%Y-%m-%d %H:%M:%S')

plt.plot(time, data['close'])
plt.show()

plt.plot(time, data['ma7'])
plt.show()
# Out:
# C:\Users\longf.DESKTOP-7QSFE46\Anaconda3\envs\keras\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
import arrow

now = arrow.now()
print(now.date())
print(now.time())
# Out:
# 2019-07-18
# 09:35:16.826377

# %%
print(now.shift(months=-5).date())
# Out:
# 2019-02-18
